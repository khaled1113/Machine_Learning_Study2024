# %%
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
from lab_utils_uni import plt_intuition, plt_stationary, plt_update_onclick, soup_bowl
plt.style.use('./deeplearning.mplstyle')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 4
#       2 get_ipython().run_line_magic('matplotlib', 'widget')
#       3 import matplotlib.pyplot as plt
# ----> 4 from lab_utils_uni import plt_intuition, plt_stationary, plt_update_onclick, soup_bowl
#       5 plt.style.use('./deeplearning.mplstyle')
#
# ImportError: cannot import name 'plt_intuition' from 'lab_utils_uni' (c:\Users\kmr44\سطح المكتب\Machine Learning coding\Machine_Learning_Study2024\Andrew ng course\lab_utils_uni.py)

# %%
x_train =np.array([1.0,2.0])
y_train =np.array([300.0,500,0])

# %%
#computing the cost function
def compute_cost(x, y, w, b): 
    """
    Computes the cost function for linear regression.
    
    Args:
      x (ndarray (m,)): Data, m examples 
      y (ndarray (m,)): target values
      w,b (scalar)    : model parameters  
    
    Returns
        total_cost (float): The cost of using w,b as the parameters for linear regression
               to fit the data points in x and y
    """
    # number of training examples
    m = x.shape[0] 
    
    cost_sum = 0 
    for i in range(m): 
        f_wb = w * x[i] + b   
        cost = (f_wb - y[i]) ** 2  
        cost_sum = cost_sum + cost  
    total_cost = (1 / (2 * m)) * cost_sum  

    return total_cost

# %%
plt_intuition(x_train,y_train)
